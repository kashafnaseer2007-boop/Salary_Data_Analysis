# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv('experience_salary_dataset.csv')
df
# Out:
#     Years of Experience  Salary
# 0                  10.5   85200
# 1                  10.9   84000
# 2                  11.1   86500
# 3                  11.3   88100
# 4                  11.7   87300
# 5                  12.0   89000
# 6                  12.4   91500
# 7                  12.8   93800
# 8                  13.0   92000
# 9                  13.6   95200
# 10                 13.9   94700
# 11                 14.0   97500
# 12                 14.1   96800
# 13                 14.2   95100
# 14                 14.8   98400
# 15                 14.9   97000
# 16                 15.0   99600
# 17                 15.5  100800
# 18                 15.7  101200
# 19                 15.8   99900
# 20                 16.3  103500
# 21                 16.5  104100
# 22                 16.6  102700
# 23                 16.8  105000
# 24                 16.9  103200
# 25                 17.7  106800
# 26                 17.9  107500
# 27                 18.0  105900
# ...

# %%
df.shape
# Out:
# (30, 2)

# %%
df.head()
# Out:
#    Years of Experience  Salary
# 0                 10.5   85200
# 1                 10.9   84000
# 2                 11.1   86500
# 3                 11.3   88100
# 4                 11.7   87300

# %%
X_train ,X_test ,Y_train ,Y_test =train_test_split(df[["Years of Experience"]],df["Salary"],random_state=42,test_size=0.2)

# %%
print(X_train)
print(X_test)
print(Y_train)
print(Y_test)
# Out:
#     Years of Experience
# 28                 18.9
# 24                 16.9
# 12                 14.1
# 0                  10.5
# 4                  11.7
# 16                 15.0
# 5                  12.0
# 13                 14.2
# 11                 14.0
# 22                 16.6
# 1                  10.9
# 2                  11.1
# 25                 17.7
# 3                  11.3
# 21                 16.5
# 26                 17.9
# 18                 15.7
# 29                 19.0
# 20                 16.3
# 7                  12.8
# 10                 13.9
# 14                 14.8
# 19                 15.8
# 6                  12.4
#     Years of Experience
# 27                 18.0
# 15                 14.9
# 23                 16.8
# 17                 15.5
# 8                  13.0
# 9                  13.6
# 28    108300
# 24    103200
# 12     96800
# 0      85200
# 4      87300
# 16     99600
# 5      89000
# 13     95100
# 11     97500
# 22    102700
# 1      84000
# ...

# %%
# X_train, Y_train, X_test, Y_test =train_test_split(df[["Years of Experience"]],df["Salary"],random_state=42,test_size=0.2)

# %%
# print(X_train)
# print(Y_train)
# print(X_test)
# print(Y_test)

# %%
LR = LinearRegression()
LR.fit(X_train,Y_train)
print(LR)
# Out:
# LinearRegression()

# %%
Y_pred=LR.predict(X_test)
print(Y_pred)
# Out:
# [107456.74419854  98222.45434035 103882.18038247 100009.73624839
#   92562.72829824  94350.01020627]

# %%
Y_test
# Out:
# 27    105900
# 15     97000
# 23    105000
# 17    100800
# 8      92000
# 9      95200
# Name: Salary, dtype: int64

# %%
print(f' Expected:\n{Y_test},\n\n Predicted:\n {Y_pred}')
# Out:
#  Expected:
# 27    105900
# 15     97000
# 23    105000
# 17    100800
# 8      92000
# 9      95200
# Name: Salary, dtype: int64,
#
#  Predicted:
#  [107456.74419854  98222.45434035 103882.18038247 100009.73624839
#   92562.72829824  94350.01020627]

# %%
import matplotlib.pyplot as plt
plt.scatter(df["Years of Experience"],df["Salary"])
plt.plot(X_test,Y_pred,color="red")
plt.show()

# %%
X_test
# Out:
#     Years of Experience
# 27                 18.0
# 15                 14.9
# 23                 16.8
# 17                 15.5
# 8                  13.0
# 9                  13.6
